# %% [markdown]
# # Zero Parameter Structure
#
# ## Minimal End-to-End Notebook — Version 1.0
#
# This notebook follows the equations presented in `README.md` and the executable
# relations in `example.py`, organized sector by sector for direct inspection.
#
# Version 1.0 replaces the earlier finite-geometric origin of the common ratios
# with the minimal causal-inheritance construction. The downstream sector
# relations beginning with the derived `R` and `S` values are unchanged.
#
# It covers cosmology, electromagnetic coupling and mass hierarchy, gravity,
# quark masses, neutrino masses, Higgs/electroweak/strong-coupling scales,
# and cosmological and local kinematic scales.
#
# **No free parameters. No tuning. Only structure.**

# %% [markdown]
# ## Common Structural Definitions
#
# ### Minimal causal-inheritance construction
#
# Use the discrete unit shift
#
# $$
# A^\sharp=A+1,
# \qquad
# A^\flat=A-1.
# $$
#
# The minimal nontrivial inheritance conditions select
#
# $$
# q=2,
# \qquad
# q^\sharp=q+1=3.
# $$
#
# The generated structural sequences are
#
# $$
# X(n,s)=q^\sharp q^n+s,
# \qquad
# X(n)=X(n,0),
# $$
#
# $$
# Y(n)=q^{n+1}-1.
# $$
#
# The unit-normalized product map is
#
# $$
# P(n)=\frac{X(n)Y(n)}{q^\sharp},
# $$
#
# with
#
# $$
# \bigl(P(1),P(q),P(q^2)\bigr)=(6,28,496).
# $$
#
# The structural ratios are defined directly from the generated $X/Y$ hierarchy:
#
# $$
# R
# =
# \frac{X(q)^\sharp}{X(1)}
# =
# \frac{13}{6},
# $$
#
# $$
# S
# =
# \frac{Y(q^2)}{X(q^\sharp)}
# =
# \frac{31}{24}.
# $$
#
# Since $X(q^2)=qX(q^\sharp)$,
#
# $$
# \frac{q}{S}
# =
# \frac{X(q^2)}{Y(q^2)}
# =
# \frac{48}{31}.
# $$
#
# The product-map formulas for $R$, $S$, and $R-S$ are retained as exact
# equivalent closure relations rather than as their primary definitions.
#
# ### Legacy downstream interface
#
# The existing sector-level formulas below retain
#
# $$
# P_{\min}=2,
# \qquad
# P_{\mathrm{mid}}=5,
# \qquad
# P_{\max}=7.
# $$
#
# These compatibility labels are distinct from the foundational product-map
# values $(P(1),P(q),P(q^2))=(6,28,496)$.
#
# ### Derived common branch structure
#
# The common branches are
#
# $$
# B_{\alpha}=\frac{3R^2}{S},
# \qquad
# B_q=3R^2S,
# \qquad
# A_d=\frac{8R}{S},
# \qquad
# A_{\tau}=8RS,
# $$
#
# with
#
# $$
# A_u=\pi R A_d.
# $$
#
# These branch quantities are derived from $R$ and $S$ and are inherited by
# the sector-specific relations below.

# %%
from fractions import Fraction
import math

c = 299792458       # exact, m/s
h = 6.62607015e-34  # exact, J s
hbar = h / (2 * math.pi)
AU_M = 149597870700

# =========================================================
# Version 1.0 minimal axiomatic structure
# =========================================================

q = 2
q_sharp = q + 1

def X(n: int, s: int = 0) -> int:
    return q_sharp * q**n + s

def Y(n: int) -> int:
    return q**(n + 1) - 1

def P(n: int) -> int:
    numerator = X(n) * Y(n)
    assert numerator % q_sharp == 0
    return numerator // q_sharp

P1 = P(1)
P2 = P(q)
P3 = P(q**2)

R = Fraction(X(q, +1), X(1))
S = Fraction(Y(q**2), X(q_sharp))

assert (q, q_sharp) == (2, 3)
assert (P1, P2, P3) == (6, 28, 496)
assert X(q**2) == q * X(q_sharp)
assert Fraction(q, 1) / S == Fraction(X(q**2), Y(q**2))
assert R == Fraction(q, 1) + Fraction(1, P1)
assert S == Fraction(P3, P1 * q**P1)
assert R - S == Fraction(P2, q**(P1 - 1))

# Legacy downstream interface retained unchanged.
P_MIN = 2
P_MID = 5
P_MAX = 7

# Derived common branches.
B_alpha = 3 * R**2 / S
B_q     = 3 * R**2 * S
A_d     = 8 * R / S
A_tau   = 8 * R * S
A_u     = math.pi * R * A_d

def alpha2_transfer(alpha_value: float, i: int, j: int) -> float:
    # Return alpha^2_[i->j] = alpha^(2(i-j)).
    return alpha_value ** (2 * (i - j))


def print_rows(rows: list[tuple[str, float, str, str]]) -> None:
    # Print rows as name, formatted value, and optional unit.
    for name, value, unit, number_format in rows:
        value_text = format(float(value), number_format)
        print(f"{name:<18} = {value_text:>20} {unit:<8}")

print("Minimal axiomatic common structure")
print("---------------------------------")
print(f"q             = {q}")
print(f"q_sharp       = {q_sharp}")
print(f"P1, P2, P3    = {P1}, {P2}, {P3}")
print(f"P_MIN         = {P_MIN}")
print(f"P_MID         = {P_MID}")
print(f"P_MAX         = {P_MAX}")
print(f"R             = {R} = {float(R):.12f}")
print(f"S             = {S} = {float(S):.12f}")
print(f"q/S           = {Fraction(q, 1) / S} = {float(Fraction(q, 1) / S):.12f}")
print(f"B_alpha       = {B_alpha} = {float(B_alpha):.12f}")
print(f"B_q           = {B_q} = {float(B_q):.12f}")
print(f"A_d           = {A_d} = {float(A_d):.12f}")
print(f"A_tau         = {A_tau} = {float(A_tau):.12f}")
print(f"A_u           = {float(A_u):.12f}")

# %% [markdown]
# ## Cosmology
#
# The density parameters are generated from the same structural ratio `R`:
#
# $$
# \Omega_b = \frac{1}{3R^2+3R},
# \qquad
# \Omega_m = 3R\Omega_b,
# \qquad
# \Omega_\Lambda = 3R^2\Omega_b,
# \qquad
# \Omega_{dm} = \Omega_m - \Omega_b.
# $$
#
# These relations imply the compact consistency relation
#
# $$
# \Omega_m^2 = 3\Omega_\Lambda\Omega_b.
# $$

# %%
Omega_b  = 1 / (3 * R**2 + 3 * R)
Omega_m  = 3 * R    * Omega_b
Omega_L  = 3 * R**2 * Omega_b
Omega_dm = Omega_m - Omega_b

print("Cosmology")
print("---------")
print(f"Omega_L  = {float(Omega_L):.12f} = {Omega_L}")
print(f"Omega_m  = {float(Omega_m):.12f} = {Omega_m}")
print(f"Omega_dm = {float(Omega_dm):.12f} = {Omega_dm}")
print(f"Omega_b  = {float(Omega_b):.12f} = {Omega_b}")
print()
print(f"Consistency residual = {float(Omega_m**2 - 3 * Omega_L * Omega_b):.3e}")

# %% [markdown]
# ## Electromagnetic Coupling and Mass Hierarchy
#
# The effective structural indices are generated from the common structural values above through fixed backbone values and residual structural corrections.
#
# The backbone values are
#
# $$
# \Psi_{e0}
# =
# \left(
# \frac{3}{2}
# \right)
# \frac{13\cdot31^2-P_{\max}^2}{3},
# \qquad
# \Psi_{p0}
# =
# \left(
# \frac{3}{2}
# \right)
# \frac{13^2\cdot31+P_{\max}^2}{12},
# $$
#
# $$
# \Psi_{n0}
# =
# \left(
# \frac{3}{2}
# \right)
# \left(
# 13\cdot31+P_{\min}^2
# \right)12,
# \qquad
# \Psi_{\mu0}
# =
# \frac{\Psi_{p0}}{P_{\min}^2},
# \qquad
# \Psi_{\tau0}
# =
# \Psi_{p0}.
# $$
#
# The residual structural corrections are
#
# $$
# \delta_e
# =
# \frac{1}{2}
# +
# \frac{1}{P_{\mathrm{mid}}^2},
# \qquad
# \delta_p
# =
# \frac{6^2}
# {\Psi_{e0}+24-\frac{1}{2}},
# \qquad
# \delta_n
# =
# \left(
# \frac{2}{3}
# \right)
# \frac{12P_{\max}-1}
# {12P_{\max}+3},
# $$
#
# $$
# \delta_\mu
# =
# \frac{1}{2}
# -
# \frac{1}{P_{\max}^2}
# +
# \frac{1}
# {\Psi_{\mu0}P_{\max}^2},
# \qquad
# \delta_\tau=1.
# $$
#
# The effective indices are therefore
#
# $$
# \Psi_e^{\mathrm{eff}}
# =
# \Psi_{e0}-\delta_e,
# \qquad
# \Psi_p^{\mathrm{eff}}
# =
# \Psi_{p0}+\delta_p,
# \qquad
# \Psi_n^{\mathrm{eff}}
# =
# \Psi_{n0}-\delta_n,
# $$
#
# $$
# \Psi_\mu^{\mathrm{eff}}
# =
# \Psi_{\mu0}-\delta_\mu,
# \qquad
# \Psi_\tau^{\mathrm{eff}}
# =
# \Psi_{\tau0}+\delta_\tau.
# $$
#
# The inverse electromagnetic coupling is then
#
# $$
# \alpha^{-1}
# =
# 4\pi B_{\alpha}
# \left(
# 1+\frac{1}{\Psi_e^{\mathrm{eff}}}
# \right).
# $$
#
# The charged-particle mass ratios are then written as
#
# $$
# \frac{m_p}{m_e}
# =
# \alpha^{-1}A_d
# \left(
# 1-\frac{1}{\Psi_p^{\mathrm{eff}}}
# \right),
# \qquad
# \frac{m_n}{m_e}
# =
# \alpha^{-1}A_d
# \left(
# 1-\frac{1}{\Psi_n^{\mathrm{eff}}}
# \right),
# $$
#
# $$
# \frac{m_\mu}{m_e}
# =
# \left(
# \frac{3}{2}
# \right)
# 4\pi B_{\alpha}
# \left(
# 1+\frac{1}{\Psi_\mu^{\mathrm{eff}}}
# \right),
# \qquad
# \frac{m_\tau}{m_\mu}
# =
# \left(
# \frac{3}{4}
# \right)
# A_{\tau}
# \left(
# 1+\frac{1}{\Psi_\tau^{\mathrm{eff}}}
# \right),
# $$
#
# with
#
# $$
# \frac{m_\tau}{m_e}
# =
# \frac{m_\tau}{m_\mu}
# \frac{m_\mu}{m_e}.
# $$
#
# The electron mass-energy scale is obtained from the structural mass path
#
# $$
# \Psi_{m_e}^{*}
# =
# 24\left[
# \frac{3}{2}RS(6\cdot24)-1
# \right],
# \qquad
# \Psi_{m_e}
# =
# 12\Psi_{m_e}^{*}
# +
# \frac{\Psi_{e0}}{3},
# $$
#
# $$
# m_e c^2
# =
# \frac{(c/10^3)^2}
# {\Psi_{m_e}\left[1+(\Psi_{m_e}^{*})^{-2}\right]} 10^{-6}
# \ \mathrm{MeV}.
# $$

# %%
core_13 = R * 6
core_31 = S * 24

# Structural backbone values Psi_0.
psi_e0   = Fraction(3, 2) * (core_13    * core_31**2 - P_MAX**2) / 3
psi_p0   = Fraction(3, 2) * (core_13**2 * core_31    + P_MAX**2) / 12
psi_n0   = Fraction(3, 2) * (core_13    * core_31    + P_MIN**2) * 12
psi_mu0  = Fraction(psi_p0, P_MIN**2)
psi_tau0 = psi_p0

# Residual structural fluctuations delta_psi.
delta_e   = Fraction(1, 2) + Fraction(1, P_MID**2)
delta_p   = Fraction(6**2) * Fraction(1, psi_e0 + 24 - Fraction(1, 2))
delta_n   = Fraction(2, 3) * Fraction(12*P_MAX - 1, 12*P_MAX + 3)
delta_mu  = Fraction(1, 2) - Fraction(1, P_MAX**2) + Fraction(1, (psi_mu0 * P_MAX**2))
delta_tau = Fraction(1, 1)

psi_e     = psi_e0   - delta_e
psi_p     = psi_p0   + delta_p
psi_n     = psi_n0   - delta_n
psi_mu    = psi_mu0  - delta_mu
psi_tau   = psi_tau0 + delta_tau

alpha_inv =         4*math.pi * B_alpha * (1 + 1/psi_e)
mmu_me    = (3/2) * 4*math.pi * B_alpha * (1 + 1/psi_mu)
mtau_mmu  = (3/4)             * A_tau * (1 + 1/psi_tau)
mp_me     =         alpha_inv * A_d * (1 - 1/psi_p)
mn_me     =         alpha_inv * A_d * (1 - 1/psi_n)
mtau_me   = mtau_mmu * mmu_me

alpha = alpha_inv**-1

# Electron rest energy in MeV.
# The expression is kept close to the structural form used in the paper code.
psi_me_star = 24 * (Fraction(3, 2) * (R * S) * (6 * 24) - 1)
psi_me      = 12 * psi_me_star + Fraction(psi_e0, 3)
me_ev       = Fraction(c, 10**3) ** 2 / (psi_me * (1 + psi_me_star**-2))
me_mev      = me_ev * 10**-6  # MeV
me_gev      = me_ev * 10**-9  # GeV

print("Electromagnetic coupling and mass hierarchy")
print("--------------------------------------------")
print_rows([
    ("Psi_e", psi_e, "", ".12f"),
    ("Psi_p", psi_p, "", ".12f"),
    ("Psi_n", psi_n, "", ".12f"),
    ("Psi_mu", psi_mu, "", ".12f"),
    ("Psi_tau", psi_tau, "", ".12f"),
    ("alpha^-1", alpha_inv, "", ".12f"),
    ("alpha", alpha, "", ".12e"),
    ("m_p / m_e", mp_me, "", ".12f"),
    ("m_n / m_e", mn_me, "", ".12f"),
    ("m_mu / m_e", mmu_me, "", ".12f"),
    ("m_tau / m_mu", mtau_mmu, "", ".12f"),
    ("m_tau / m_e", mtau_me, "", ".12f"),
    ("Psi_me*", psi_me_star, "", ".12f"),
    ("Psi_me", psi_me, "", ".12f"),
    ("m_e c^2", me_ev, "eV", ".9f"),
    ("m_e c^2", me_mev, "MeV", ".15f"),
    ("m_e c^2", me_gev, "GeV", ".14e"),
])

# %% [markdown]
# ## Gravity
#
# The gravity-sector structural indices are
#
# $$
# \Psi_G
# =
# 8R\left[(3R)(3S)-P_{\min}^2\right],
# \qquad
# \Psi_{G0}
# =
# RS^2(12\cdot24),
# $$
#
# $$
# \Psi_G^{*}
# =
# 4\Psi_G
# -
# 3\left(
# 1+\frac{1}{\Psi_{G0}}
# \right).
# $$
#
# Using the inherited electromagnetic coupling and the common branch
# $A_d=8R/S$, the gravitational relation is written as
#
# $$
# G^{-1/2}
# =
# \alpha^{-1}A_d\pi
# \left[
# (3R)(3S)-P_{\min}^2
# \right],
# $$
#
# or equivalently
#
# $$
# \sqrt{G}
# =
# \left\{
# \alpha^{-1}A_d\pi
# \left[
# (3R)(3S)-P_{\min}^2
# \right]
# \right\}^{-1},
# \qquad
# G=(\sqrt{G})^2.
# $$
#
# The SI mass scales are connected through
#
# $$
# M_{\mathrm{Pl}}
# =
# \sqrt{\frac{\hbar c}{G}},
# $$
#
# $$
# M_p
# =
# M_{\mathrm{Pl}}
# \alpha^{12}
# \left(
# \frac{m_p}{m_e}
# \right)^2
# \left(
# 1+\frac{1}{\Psi_G^{*}}
# \right)^{-1/2},
# $$
#
# $$
# M_e
# =
# M_{\mathrm{Pl}}
# \alpha^{12}
# \left(
# \frac{m_p}{m_e}
# \right)
# \left(
# 1+\frac{1}{\Psi_G^{*}}
# \right)^{-1/2}.
# $$

# %%
psi_g      = 8 * R * ((3 * R) * (3 * S) - P_MIN**2)
psi_g0     = R * S**2 * (12 * 24)
psi_g_star = 4 * psi_g - 3 * (1 + 1 / psi_g0)

G_inv_sqrt = (1 / alpha) * A_d * math.pi * ((3 * R) * (3 * S) - P_MIN**2)
sqrt_G     = 1 / G_inv_sqrt
G          = sqrt_G**2
alpha_Gp = alpha**24 * mp_me**4 / (1 + 1 / psi_g_star)
alpha_Ge = alpha**24 * mp_me**2 / (1 + 1 / psi_g_star)

g_corr = (1 + 1 / psi_g_star)**(-1/2)
M_Pl   = math.sqrt(hbar * c / G)
M_P    = M_Pl * alpha**12 * mp_me**2 * g_corr
M_E    = M_Pl * alpha**12 * mp_me    * g_corr

print("Gravity")
print("-------")
print_rows([
    ("Psi_G", psi_g, "", ".12f"),
    ("Psi_G*", psi_g_star, "", ".12f"),
    ("sqrt(G)", sqrt_G, "", ".12e"),
    ("G", G, "", ".12e"),
    ("alpha_Gp", alpha_Gp, "", ".12e"),
    ("alpha_Ge", alpha_Ge, "", ".12e"),
    ("M_Pl", M_Pl, "kg", ".12e"),
    ("M_P", M_P, "kg", ".12e"),
    ("M_E", M_E, "kg", ".12e"),
])

# %% [markdown]
# ## Quark Masses
#
# The quark masses are generated by the unified relation
#
# $$
# \frac{m_q}{m_e}
# =
# K_q B_q A_q^{n_q},
# \qquad
# B_q = 3R^2S.
# $$
#
# The branch amplification factors are
#
# $$
# A_q =
# \begin{cases}
# A_u & (q=u,c,t), \\
# A_d & (q=d,s,b),
# \end{cases}
# \qquad
# A_d = \frac{8R}{S},
# \qquad
# A_u = \pi R A_d.
# $$
#
# Equivalently,
#
# $$
# A_d = \frac{8R}{S},
# \qquad
# A_u = \frac{8\pi R^2}{S}.
# $$
#
# The structural coefficients are written directly as
#
# $$
# (K_u,K_d,K_c,K_s,K_t,K_b)
# =
# \left(
# \frac{1}{2R},\,
# \frac{1}{2},\,
# 1+\frac{1}{2},\,
# 1-\frac{1}{4},\,
# 2+\frac{1}{2R},\,
# 2+\frac{1}{2}
# \right).
# $$
#
# The generation index is
#
# $$
# n_q =
# \begin{cases}
# 0 & (u,d), \\
# 1 & (c,s), \\
# 2 & (t,b).
# \end{cases}
# $$

# %%
K_q = {
    "u": (    1 / (2 * R)),
    "d": (    1 /  2),
    "c": (1 + 1 /  2),
    "s": (1 - 1 /  4),
    "t": (2 + 1 / (2 * R)),
    "b": (2 + 1 /  2),
}

m_u = me_mev * K_q["u"] * B_q
m_d = me_mev * K_q["d"] * B_q
m_c = me_mev * K_q["c"] * B_q * A_u
m_s = me_mev * K_q["s"] * B_q * A_d
m_t = me_gev * K_q["t"] * B_q * A_u**2
m_b = me_gev * K_q["b"] * B_q * A_d**2

print("Quark masses")
print("------------")
print_rows([
    ("B_q", B_q, "", ".12f"),
    ("A_u", A_u, "", ".12f"),
    ("A_d", A_d, "", ".12f"),
    ("m_u", m_u, "MeV", ".12f"),
    ("m_d", m_d, "MeV", ".12f"),
    ("m_c", m_c, "MeV", ".12f"),
    ("m_s", m_s, "MeV", ".12f"),
    ("m_t", m_t, "GeV", ".12f"),
    ("m_b", m_b, "GeV", ".12f"),
])

# %% [markdown]
# ## Neutrino Masses
#
# Using the structural-transfer notation
#
# $$
# \alpha^2_{[i\to j]}
# =
# \alpha^{2(i-j)},
# $$
#
# the common neutrino base structure is
#
# $$
# B_\nu
# =
# 12S\alpha^2_{[2\to0]}
# =
# 12S\alpha^4.
# $$
#
# The three neutrino mass ratios are generated by the unified relation
#
# $$
# \frac{m_{\nu,n}}{m_e}
# =
# B_\nu(n+\Phi_n),
# \qquad
# n=0,1,2,
# $$
#
# with fixed branch factors
#
# $$
# \Phi_0=1,
# \qquad
# \Phi_1=\frac{1}{3R^2},
# \qquad
# \Phi_2=\frac{1}{R}.
# $$
#
# The displayed labels $m_{\nu1}$, $m_{\nu2}$, and $m_{\nu3}$
# correspond respectively to $n=0,1,2$.  The mass-squared differences are
#
# $$
# \Delta m_{21}^2
# =
# m_{\nu2}^2-m_{\nu1}^2,
# \qquad
# \Delta m_{31}^2
# =
# m_{\nu3}^2-m_{\nu1}^2,
# \qquad
# \Delta m_{32}^2
# =
# m_{\nu3}^2-m_{\nu2}^2,
# $$
#
# $$
# \sum m_\nu
# =
# m_{\nu1}+m_{\nu2}+m_{\nu3}.
# $$

# %%
B_nu = 12 * S * alpha2_transfer(alpha, 2, 0)

phi_nu = (
    1,
    1 / (3 * R**2),
    1 / R,
)

# Dimensionless mass ratios m_nu,n / m_e for n = 0, 1, 2.
nu_mass_ratios = tuple(
    B_nu * (n + phi_nu[n])
    for n in range(3)
)

# Absolute neutrino masses in eV.
m_nu1_ev, m_nu2_ev, m_nu3_ev = tuple(
    ratio * me_ev
    for ratio in nu_mass_ratios
)

dm21 = m_nu2_ev**2 - m_nu1_ev**2
dm31 = m_nu3_ev**2 - m_nu1_ev**2
dm32 = m_nu3_ev**2 - m_nu2_ev**2
sum_mnu = m_nu1_ev + m_nu2_ev + m_nu3_ev

print("Neutrino masses")
print("----------------")
print_rows([
    ("m1 / m_e", nu_mass_ratios[0], "", ".12e"),
    ("m2 / m_e", nu_mass_ratios[1], "", ".12e"),
    ("m3 / m_e", nu_mass_ratios[2], "", ".12e"),
    ("m1 c^2", m_nu1_ev, "eV", ".12f"),
    ("m2 c^2", m_nu2_ev, "eV", ".12f"),
    ("m3 c^2", m_nu3_ev, "eV", ".12f"),
    ("Sum m_nu", sum_mnu, "eV", ".12f"),
    ("Delta m21^2", dm21, "eV^2", ".12e"),
    ("Delta m31^2", dm31, "eV^2", ".12e"),
    ("Delta m32^2", dm32, "eV^2", ".12e"),
])

# %% [markdown]
# ## Higgs, Electroweak, and Strong-Coupling Scales
#
# The Higgs-sector base structure is
#
# $$
# B_H
# =
# 12R\alpha^2_{[1\to2]}
# =
# 12R\alpha^{-2}.
# $$
#
# The Higgs mass and electroweak vacuum expectation value are represented by
#
# $$
# \frac{m_H}{m_e}
# =
# \frac{1}{2}B_H+\Psi_H,
# \qquad
# \frac{v}{m_e}
# =
# B_H-\Psi_v,
# $$
#
# The Higgs-sector structural indices are generated directly from the common branch ratio \(R\):
#
# $$
# \Psi_H
# =
# 12\left[
# 4(3R^2)+3
# \right]
# =
# 712,
# \qquad
# \Psi_v
# =
# 3^2\Psi_H
# =
# 6408.
# $$
#
# The electron Yukawa coupling follows from the vacuum-scale ratio:
#
# $$
#  y_e
#  =
#  \frac{\sqrt{2}}{v/m_e}
#  =
#  \frac{\sqrt{2}\,m_e}{v}.
# $$
#
# The weak mixing relation is
#
# $$
# \sin^2\theta_W
# =
# 2\pi\alpha R^2
# \left(
# 1+3^{-3}
# \right),
# \qquad
# \cos\theta_W
# =
# \sqrt{1-\sin^2\theta_W}.
# $$
#
# The \(W\)-boson mass ratio and physical mass scale are
#
# $$
# \frac{m_W}{m_e}
# =
# \frac{y_e^{-1}}{R}
# \left(
# 1+\frac{1}{\Psi_v}
# \right).
# $$
#
# The \(Z\)-boson mass is then
#
# $$
# m_Z
# =
# \frac{m_W}{\cos\theta_W}.
# $$
#
# Finally, the structural boundary value of the strong coupling is
#
# $$
# \alpha_s(m_Z)
# =
# 1-\frac{m_W}{m_Z}.
# $$

# %%
# Higgs-sector base structure and fixed structural integers.
B_H   = 12 * R * alpha2_transfer(alpha, 1, 2)
Psi_H = 12 * (4 * (3 * R**2) + 3)
Psi_v = 3**2 * Psi_H

# Higgs and vacuum scales.
mH_over_me = (1 / 2.0) * B_H + Psi_H
v_over_me  = B_H - Psi_v
mH_GeV     = mH_over_me * me_gev
v_GeV      = v_over_me  * me_gev

# Electron Yukawa and weak-sector values.
ye = math.sqrt(2) / v_over_me
sin2_thetaW = 2 * math.pi * alpha * R**2 * (1 + 3**-3)
cos_thetaW  = math.sqrt(1 - sin2_thetaW)
mW_over_me  = (1 / ye) / R * (1 + 1 / Psi_v)
mW_GeV      = mW_over_me * me_gev
mZ_GeV      = mW_GeV / cos_thetaW
alpha_s_mZ  = 1 - mW_GeV / mZ_GeV

print("Higgs, electroweak, and strong-coupling scales")
print("----------------------------------------------")
print_rows([
    ("B_H", B_H, "", ".12f"),
    ("Psi_H", Psi_H, "", ".0f"),
    ("Psi_v", Psi_v, "", ".0f"),
    ("m_H / m_e", mH_over_me, "", ".12f"),
    ("v / m_e", v_over_me, "", ".12f"),
    ("m_H", mH_GeV, "GeV", ".12f"),
    ("v", v_GeV, "GeV", ".12f"),
    ("y_e", ye, "", ".12e"),
    ("sin^2(theta_W)", sin2_thetaW, "", ".12f"),
    ("m_W / m_e", mW_over_me, "", ".12f"),
    ("m_W", mW_GeV, "GeV", ".12f"),
    ("m_Z", mZ_GeV, "GeV", ".12f"),
    ("alpha_s(m_Z)", alpha_s_mZ, "", ".12f"),
])

# %% [markdown]
# ## Cosmological and Local Kinematic Scales
#
# Using the common branch $B_{\alpha}$ and the inherited effective electron index,
# the physical baryon density parameter and structural Hubble scale are written as
#
# $$
# \Omega_{b,\mathrm{st}}
# =
# \frac{1}{3R^2+3R},
# \qquad
# \omega_{\mathrm{st}}
# =
# \frac{4\pi B_{\alpha}}
# {\Psi_e^{\mathrm{eff}}},
# $$
#
# $$
# H_{\mathrm{st}}
# =
# 100
# \sqrt{
# \frac{\omega_{\mathrm{st}}}
# {\Omega_{b,\mathrm{st}}}
# }
# \ \mathrm{km\,s^{-1}\,Mpc^{-1}}.
# $$
#
# The corresponding local distance-ladder scale is
#
# $$
# H_{\mathrm{ladder,st}}
# =
# \left(
# \frac{R}{2}
# \right)
# H_{\mathrm{st}}.
# $$
#
# For the time, acceleration, closure, and velocity relations,
# $H_{\mathrm{st}}$ is first converted to SI units:
#
# $$
# H_{\mathrm{st}}^{\mathrm{SI}}
# =
# H_{\mathrm{st}}
# \frac{10^3}{\mathrm{Mpc}}
# \ \mathrm{s^{-1}}.
# $$
#
# The structural time and acceleration scales are then
#
# $$
# T_{\alpha,\mathrm{st}}
# =
# B_{\alpha}
# \left(
# H_{\mathrm{st}}^{\mathrm{SI}}
# \right)^{-1},
# \qquad
# a_{\mathrm{st}}
# =
# 2c
# T_{\alpha,\mathrm{st}}^{-1}.
# $$
#
# The speed-of-light closure relation is
#
# $$
# c
# =
# \frac{1}{2}
# a_{\mathrm{st}}
# B_{\alpha}
# \left(
# H_{\mathrm{st}}^{\mathrm{SI}}
# \right)^{-1}.
# $$
#
# The corresponding Local Sheet velocity scale is
#
# $$
# v_{\mathrm{LS,st}}
# =
# \frac{1}{8}
# a_{\mathrm{st}}
# B_{\alpha}^{-1}
# \left(
# H_{\mathrm{st}}^{\mathrm{SI}}
# \right)^{-1}.
# $$

# %%
omega_st = 4 * math.pi * B_alpha / psi_e
H_st     = 100 * (omega_st / Omega_b)**0.5  # km/s/Mpc

Mpc_m    = (AU_M * 60**2 / (math.pi / 180.0)) * 10**6
H_st_si  = H_st * 10**3 / Mpc_m

H_ladder_st = (R / 2) * H_st
T_alpha_st  = B_alpha * H_st_si**-1
a_st        = 2 * c * T_alpha_st**-1

c_closure = Fraction(1, 2) * a_st * B_alpha     * H_st_si**-1
v_LS_st   = Fraction(1, 8) * a_st * B_alpha**-1 * H_st_si**-1

print("Cosmological and Local Kinematic Scales")
print("---------------------------------------")
print_rows([
    ("omega_st", omega_st, "", ".12f"),
    ("H_st", H_st, "km/s/Mpc", ".12f"),
    ("H_ladder_st", H_ladder_st, "km/s/Mpc", ".12f"),
    ("T_alpha_st", T_alpha_st, "s", ".12e"),
    ("a_st", a_st, "m/s^2", ".12e"),
    ("c_closure", c_closure / 1000, "km/s", ".3f"),
    ("v_LS_st", v_LS_st / 1000, "km/s", ".3f"),
])

# %% [markdown]
# ---
#
# ## Reproducibility Note
#
# All cells use only the Python standard library. Run the notebook from top to bottom.
#
# For full theory-vs-observation comparisons:
#
# ```bash
# python -m code.paper1_cosmology
# python -m code.paper2_electron
# python -m code.paper3_gravity
# python -m code.paper4_quark_mass
# python -m code.paper5_neutrino
# python -m code.paper6_higgs_electroweak
# python -m code.paper7_cosmological_kinematics
# ```
